# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/Telco-Customer-Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")
df["TotalCharges"].fillna(df["TotalCharges"].median(), inplace=True)
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_18736\3396627008.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["TotalCharges"].fillna(df["TotalCharges"].median(), inplace=True)
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# ...

# %%
df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  customerID_0003-MKNFE  \
# 0              0       1           29.85         29.85                  False
# 1              0      34           56.95       1889.50                  False
# 2              0       2           53.85        108.15                  False
# 3              0      45           42.30       1840.75                  False
# 4              0       2           70.70        151.65                  False
#
#    customerID_0004-TLHLJ  customerID_0011-IGKFF  customerID_0013-EXCHZ  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
# ...

# %%
x = df.drop("Churn_Yes", axis=1)
y = df["Churn_Yes"]

# %%
x.isnull().sum()
# Out:
# SeniorCitizen                             0
# tenure                                    0
# MonthlyCharges                            0
# TotalCharges                             11
# customerID_0003-MKNFE                     0
#                                          ..
# Contract_Two year                         0
# PaperlessBilling_Yes                      0
# PaymentMethod_Credit card (automatic)     0
# PaymentMethod_Electronic check            0
# PaymentMethod_Mailed check                0
# Length: 7072, dtype: int64

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")
df["TotalCharges"].fillna(df["TotalCharges"].median(), inplace=True)
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_18736\617195598.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["TotalCharges"].fillna(df["TotalCharges"].median(), inplace=True)
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# ...

# %%
df = pd.get_dummies(df, drop_first=True)
X = df.drop("Churn_Yes", axis=1) 
y = df["Churn_Yes"]
X.isnull().sum().sum()
# Out:
# np.int64(11)

# %%
df["TotalCharges"] = df["TotalCharges"].replace(" ", np.nan)
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"])
df["TotalCharges"] = df["TotalCharges"].fillna(df["TotalCharges"].median())
df["TotalCharges"].isnull().sum()
# Out:
# np.int64(0)

# %%
df = pd.get_dummies(df, drop_first=True)
X = df.drop("Churn_Yes", axis=1)
y = df["Churn_Yes"]
X.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# c:\Users\Gabriel\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
print ("Logistic Regression:")
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Logistic Regression:
# Accuracy: 0.8088026502602934
# Precision: 0.6748971193415638
# Recall: 0.5714285714285714
# F1 Score: 0.6188679245283019

# %% [markdown]
# Si bien el modelo presenta una accuracy relativamente alta, esto se debe en parte al desbalance del dataset. Al analizar métricas como recall, se observa que el modelo no logra identificar una proporción significativa de los clientes que abandonan, lo cual limita su utilidad en un contexto real.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

plt.show()

# %% [markdown]
# A partir de la matriz de confusión se observa que el modelo presenta una cantidad considerable de falsos negativos, lo que indica que no logra identificar correctamente a todos los clientes que abandonan. Esto se refleja en un recall moderado, lo cual representa una limitación importante en un contexto real donde detectar el churn es clave.

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(random_state=42)

rf_model.fit(X_train, y_train)

y_pred_rf = rf_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Random Forest:")

print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Precision:", precision_score(y_test, y_pred_rf))
print("Recall:", recall_score(y_test, y_pred_rf))
print("F1 Score:", f1_score(y_test, y_pred_rf))
# Out:
# Random Forest:
# Accuracy: 0.8035967818267865
# Precision: 0.7226890756302521
# Recall: 0.44947735191637633
# F1 Score: 0.5542427497314716

# %% [markdown]
# Aunque Random Forest tiene mayor precisión, su bajo recall indica que no logra identificar correctamente a la mayoría de los clientes que abandonan. En este contexto, la regresión logística resulta más adecuada, ya que prioriza la detección del churn, reduciendo la cantidad de falsos negativos.

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb_model = GradientBoostingClassifier(random_state=42)
gb_model.fit(X_train, y_train)
y_pred_gb = gb_model.predict(X_test)

# %%
print("Gradient Boosting:")
print("Accuracy:", accuracy_score(y_test, y_pred_gb))
print("Precision:", precision_score(y_test, y_pred_gb))
print("Recall:", recall_score(y_test, y_pred_gb))
print("F1 Score:", f1_score(y_test, y_pred_gb))
# Out:
# Gradient Boosting:
# Accuracy: 0.8012304779933743
# Precision: 0.6905940594059405
# Recall: 0.48606271777003485
# F1 Score: 0.5705521472392638

# %%
fig, axs = plt.subplots(1, 3, figsize=(15,5))

ConfusionMatrixDisplay.from_predictions(y_test, y_pred, ax=axs[0])
axs[0].set_title("Logistic")

ConfusionMatrixDisplay.from_predictions(y_test, y_pred_rf, ax=axs[1])
axs[1].set_title("Random Forest")

ConfusionMatrixDisplay.from_predictions(y_test, y_pred_gb, ax=axs[2])
axs[2].set_title("Gradient Boosting")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusión Final
#
# En este proyecto se trabajó con un dataset de clientes de telecomunicaciones con el objetivo de predecir si un cliente abandonará el servicio (churn).
#
# Se realizó un proceso completo de preparación de datos, incluyendo limpieza de valores problemáticos en la variable `TotalCharges`, transformación de variables categóricas mediante encoding y selección de variables relevantes para el modelo.
#
# Se probaron distintos modelos de clasificación, incluyendo regresión logística, random forest y gradient boosting. A pesar de que los modelos más complejos mostraron buen desempeño en precisión, la regresión logística presentó el mejor equilibrio general, especialmente en recall, que es la métrica más relevante en este caso. Por este motivo, se selecciona este modelo como el más adecuado para el problema de churn.
#
# Tambien al comparar las matrices de confusión, se observa que la cantidad de verdaderos positivos se mantiene relativamente estable entre los modelos. Sin embargo, la principal diferencia se encuentra en los falsos negativos, donde los modelos más complejos presentan una mayor cantidad, lo que implica una menor capacidad para detectar clientes que abandonan.
#
# En conclusión, este proyecto demuestra que un modelo más complejo no siempre es mejor, y que la elección del modelo debe estar guiada por el problema de negocio y las métricas relevantes.
